# %%
! git clone https://github.com/ydixon/yolo_v3
# Out:
# Cloning into 'yolo_v3'...
# Updating files:  27% (184/663)
# Updating files:  28% (186/663)
# Updating files:  29% (193/663)
# Updating files:  30% (199/663)
# Updating files:  31% (206/663)
# Updating files:  32% (213/663)
# Updating files:  33% (219/663)
# Updating files:  34% (226/663)
# Updating files:  35% (233/663)
# Updating files:  36% (239/663)
# Updating files:  37% (246/663)
# Updating files:  38% (252/663)
# Updating files:  39% (259/663)
# Updating files:  40% (266/663)
# Updating files:  41% (272/663)
# Updating files:  42% (279/663)
# Updating files:  43% (286/663)
# Updating files:  44% (292/663)
# Updating files:  45% (299/663)
# Updating files:  46% (305/663)
# Updating files:  47% (312/663)
# Updating files:  48% (319/663)
# Updating files:  49% (325/663)
# Updating files:  50% (332/663)
# Updating files:  51% (339/663)
# Updating files:  52% (345/663)
# Updating files:  53% (352/663)
# Updating files:  54% (359/663)
# Updating files:  55% (365/663)
# ...

# %%
! cd yolo_v3

# %%
# !pip install https://pjreddie.com/media/files/yolov3.weights
# Out:
# ...
#                                               0.0/248.0 MB ? eta -:--:--
#                                               0.0/248.0 MB ? eta -:--:--
#                                               0.0/248.0 MB ? eta -:--:--
#                                               0.0/248.0 MB ? eta -:--:--
#                                               0.0/248.0 MB ? eta -:--:--
#                                             0.0/248.0 MB 140.3 kB/s eta 0:29:28
#                                             0.1/248.0 MB 350.1 kB/s eta 0:11:49
#                                             0.1/248.0 MB 350.1 kB/s eta 0:11:49
#                                             0.1/248.0 MB 350.1 kB/s eta 0:11:49
#                                             0.1/248.0 MB 350.1 kB/s eta 0:11:49
#                                             0.1/248.0 MB 226.0 kB/s eta 0:18:17
#                                             0.2/248.0 MB 414.8 kB/s eta 0:09:58
# ...

# %%
# !pip install  https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# ...
#                                               0.0/162.5 MB ? eta -:--:--
#                                               0.0/162.5 MB ? eta -:--:--
#                                               0.0/162.5 MB ? eta -:--:--
#                                               0.0/162.5 MB ? eta -:--:--
#                                               0.0/162.5 MB ? eta -:--:--
#                                             0.1/162.5 MB 234.9 kB/s eta 0:11:32
#                                             0.1/162.5 MB 350.1 kB/s eta 0:07:44
#                                             0.1/162.5 MB 350.1 kB/s eta 0:07:44
#                                             0.1/162.5 MB 350.1 kB/s eta 0:07:44
#                                             0.1/162.5 MB 350.1 kB/s eta 0:07:44
#                                             0.1/162.5 MB 226.0 kB/s eta 0:11:59
#                                             0.2/162.5 MB 415.7 kB/s eta 0:06:31
# ...

# %%
 ! cd yolo_v3/weights/COCO_ydixon
# !dir
# !pip install https://drive.google.com/drive/folders/1HPxEA7kyJxLTu0mWYu5Vlcz57NcuD2U3?usp=sharing
# Out:
# ...
#      - 0 bytes ? 0:00:00
#      - 44.1 kB 2.9 MB/s 0:00:00
#      - 63.3 kB 1.0 MB/s 0:00:00
#      \ 106.3 kB 848.5 kB/s 0:00:00
#      \ 150.6 kB 874.2 kB/s 0:00:00
#      | 219.6 kB 1.0 MB/s 0:00:00
#      / 281.0 kB 1.1 MB/s 0:00:00
#   ERROR: Cannot unpack file C:\Users\Nitro5\AppData\Local\Temp\pip-unpack-h6fm3c5x\1HPxEA7kyJxLTu0mWYu5Vlcz57NcuD2U3 (downloaded from C:\Users\Nitro5\AppData\Local\Temp\pip-req-build-0u7vw80z, content-type: text/html; charset=utf-8); cannot detect archive format
# ERROR: Cannot determine archive format of C:\Users\Nitro5\AppData\Local\Temp\pip-req-build-0u7vw80z

# %%
! cd yolo_v3/data/
